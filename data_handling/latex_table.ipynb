# %%
from experiment_data import ExperimentData, Database, Query, C

folder = "../table_latex"

db = Database.populate_from_folder(folder)

# %%
d = db.index_on("experiment_name", "instance_arguments", "solver_options")
assert all(len(x) == 40 for x in d.values())

# %%
for k in d:
    print(k)

    valid = [x for x in d[k] if x.results["termination_condition"] != "maxTimeLimit"]

    # avg_lb = sum([x.results["lower_bound"] for x in valid]) / len(valid)
    # print("avg lb: ", avg_lb)
    #
    # avg_time = sum([x.results["time"] for x in valid]) / len(valid)
    # print("avg time: ", avg_time)

    print("Number of valid runs: ", len(valid), "/ 40")
# Out:
# ('experiment_name', 'relax_w', 'instance_arguments', frozenset({('alpha', 0), ('n', 6)}), 'solver_options', 'maxtime=300')
# Number of valid runs:  34 / 40
# ('experiment_name', 'relax_w', 'instance_arguments', frozenset({('n', 4), ('alpha', 0)}), 'solver_options', 'maxtime=300')
# Number of valid runs:  40 / 40
# ('experiment_name', 'full_solutions', 'instance_arguments', frozenset({('alpha', 0), ('n', 6)}), 'solver_options', 'maxtime=300')
# Number of valid runs:  39 / 40
# ('experiment_name', 'relax', 'instance_arguments', frozenset({('n', 5), ('alpha', 0)}), 'solver_options', 'maxtime=300')
# Number of valid runs:  39 / 40
# ('experiment_name', 'relax', 'instance_arguments', frozenset({('alpha', 0), ('n', 6)}), 'solver_options', 'maxtime=300')
# Number of valid runs:  40 / 40
# ('experiment_name', 'full_solutions_preprocessing_only', 'instance_arguments', frozenset({('alpha', 0), ('n', 6)}), 'solver_options', 'maxtime=300 MaxIter=1')
# Number of valid runs:  40 / 40
# ('experiment_name', 'full_solutions_preprocessing_only', 'instance_arguments', frozenset({('n', 4), ('alpha', 0)}), 'solver_options', 'maxtime=300 MaxIter=1')
# Number of valid runs:  40 / 40
# ('experiment_name', 'full_solutions', 'instance_arguments', frozenset({('n', 4), ('alpha', 0)}), 'solver_options', 'maxtime=300')
# Number of valid runs:  40 / 40
# ('experiment_name', 'relax', 'instance_arguments', frozenset({('n', 4), ('alpha', 0)}), 'solver_options', 'maxtime=300')
# Number of valid runs:  40 / 40
# ('experiment_name', 'full_solutions', 'instance_arguments', frozenset({('n', 5), ('alpha', 0)}), 'solver_options', 'maxtime=300')
# Number of valid runs:  39 / 40
# ('experiment_name', 'relax_w', 'instance_arguments', frozenset({('n', 5), ('alpha', 0)}), 'solver_options', 'maxtime=300')
# Number of valid runs:  38 / 40
# ('experiment_name', 'full_solutions_preprocessing_only', 'instance_arguments', frozenset({('n', 5), ('alpha', 0)}), 'solver_options', 'maxtime=300 MaxIter=1')
# Number of valid runs:  40 / 40
